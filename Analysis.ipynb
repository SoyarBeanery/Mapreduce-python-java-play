# %%
# libraries
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
 
# ------- UNDIRECTED
 
# Build a dataframe with your connections
# This time a pair can appear 2 times, in one side or in the other!
df = pd.DataFrame({ 'from':['pandemic', 'coronavirus', 'vaccine', 'Wuhan','coronavirus', 'death', 'treated'], 'to':['coronavirus', 'pandemic', 'coronavirus', 'serum','Wuhan', 'treated', 'death']})
 
# Build your graph. Note that we use the Graph function to create the graph!
G=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.Graph() )
 
# Make the graph
nx.draw(G, with_labels=True, node_size=3500, alpha=0.4, arrows=True)
plt.title("WordCount Using Regular Java")
plt.show()

# %%
# ------- DIRECTED
 # libraries
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# Build a dataframe with your connections
# This time a pair can appear 2 times, in one side or in the other!
df = pd.DataFrame({ 'from':['viruses', 'vaccine', 'Wuhan', 'serum','vaccine'], 'to':['vaccine', 'viruses', 'vaccine', 'SARS','serum']})
 
# Build your graph. Note that we use the DiGraph function to create the graph!
G=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.DiGraph() )
 
# Make the graph
nx.draw(G, with_labels=True, node_size=2500, alpha=0.3, arrows=True)
plt.title("WordCount Using Python Streaming")
plt.show()

# %%
# Libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Create a list of word
text=("vaccine Wuhan SARS serum viruses treated death pandemic coronavirus")

# Create the wordcloud object
wordcloud = WordCloud(width=280, height=180, background_color='white', max_font_size=30, min_font_size=20).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.title("WordCloud Of WordCount Words")
plt.show()

# %%
# library
import matplotlib.pyplot as plt
 
# create data
names = ['vaccine', 'Wuhan', 'SARS', 'serum', 'viruses', 'treated', 'death', 'pandemic', 'coronavirus']
size = [16392,13470,9099,15493,11215,3974,5498,4894,7543]
 
# Create a circle at the center of the plot
my_circle = plt.Circle( (0,0), 0.7, color='white')

# Give color names
plt.pie(size, labels=names, colors=['red','green','blue', 'orange','skyblue', 'blueviolet', 'indigo', 'yellow','lime'])
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.title("WordCount Of Words From 'Sentence.txt'")
# Show the graph
plt.show()

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
 
# create a dataset
height = [16392, 15493 , 13470]
bars = ('vaccine', 'serum', 'Wuhan')
x_pos = np.arange(len(bars))

# Create bars with different colors
plt.bar(x_pos, height, color=['orange', 'violet', 'teal'])

# Create names on the x-axis
plt.xticks(x_pos, bars)
plt.title("Top 3 Most Related Words From WordCount")
plt.figure (figsize=(40,45))

# Show graph
plt.show()

# %%
# Libraries and data
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
df=pd.DataFrame({'x_values': range(1,6), 'y_values': np.random.randn(5) })

# Draw line chart with dashed line
plt.plot( 'x_values', 'y_values', data=df, linestyle='dashed')
plt.title("Distributed Score Of Wordcount Sentiment")
# Show graph
plt.show()
